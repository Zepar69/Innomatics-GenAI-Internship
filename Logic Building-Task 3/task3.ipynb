# %%
#Employee performance bonus eligibility

emp={"Ravi":92,"Anita":88,"Kiran":92,"Suresh":85}
top_score=max(emp.values())
top_performers=[name for name,score in emp.items() if score==top_score]
print(f"Top Performers Eligible for Bonus:{', '.join(top_performers)}(Score:{top_score})")
# Out:
# Top Performers Eligible for Bonus:Ravi, Kiran(Score:92)

# %%
#Search query keyword analysis

import re
query="Buy mobile phone buy phone online"
query=query.lower()
words=re.findall(r'\b\w+\b',query)
freq={}
for word in words:
    freq[word]=freq.get(word, 0)+1
repeated_keywords={word:count for word, count in freq.items() if count>1}
print(repeated_keywords)
# Out:
# {'buy': 2, 'phone': 2}

# %%
#Sensor data validation

sensor_readings=[3,4,7,8,10,12,5]
valid_readings=[(index,value) for index, value in enumerate(sensor_readings) if value%2==0]
print(f"Valid Sensor Readings (Hour, Value):{valid_readings}")
# Out:
# Valid Sensor Readings (Hour, Value):[(1, 4), (3, 8), (4, 10), (5, 12)]

# %%
#Email domain usage analysis

emails=["ravi@gmail.com","anita@yahoo.com","kiran@gmail.com","suresh@gmail.com","meena@yahoo.com"]
domain_count={}
for email in emails:
    domain=email.split("@")[1]
    domain_count[domain]=domain_count.get(domain,0)+1
total=len(emails)
for domain, count in domain_count.items():
    percentage=(count/total)*100
    print(f"{domain}:{int(percentage)}%")
# Out:
# gmail.com:60%
# yahoo.com:40%

# %%
#Sales spike detection

sales=[1200,1500,900,2200,1400,3000]
average=sum(sales)/len(sales)
for index, value in enumerate(sales,start=1):
    if value>average*1.3:
        print(f"Day {index}:{value}")
# Out:
# Day 6:3000

# %%
#Duplicate user id detection

user_id=["user1","user2","user1","user3","user1","user3"]
id_count={}
for uid in user_id:
    id_count[uid]=id_count.get(uid,0)+1
for uid,count in id_count.items():
    if count>1:
        print(f"{uid} -> {count}times")
# Out:
# user1 -> 3times
# user3 -> 2times
