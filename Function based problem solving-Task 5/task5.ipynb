# %%
#1.Social media post engagement analyzer

def analyze_engagement(likes_list):
    total_likes=0
    for like in likes_list:
        total_likes+=like
    status="Viral Post" if total_likes>=1000 else "Normal Engagement"
    print(f"Total Likes:{total_likes}\nPost Status:{status}")
analyze_engagement([40,666,69,500])
# Out:
# Total Likes:1275
# Post Status:Viral Post

# %%
#2.Healthcare medicing stock alert system

def check_medicine_stock(stock):
    status="Low Stock Alert" if stock<10 else "Stock Sufficient"
    print(f"Medicine Stock:{stock}\nStatus:{status}")
check_medicine_stock(10)
# Out:
# Medicine Stock:10
# Status:Stock Sufficient

# %%
#3.Agriculture rainfall adequacy checker

def check_rainfall(rainfall_list,required):
    total=0
    for r in rainfall_list:
        total+=r
    average=total/len(rainfall_list)
    status="Adequate Rainfall" if average>=required else "Inadequate Rainfall"
    print(f"Average Rainfall:{average}\nRainfall Status:{status}")
check_rainfall([69,67,87,92],70)
# Out:
# Average Rainfall:78.75
# Rainfall Status:Adequate Rainfall

# %%
#4.Social media duplicate account detection

def detect_duplicates(usernames):
    has_duplicates=len(usernames)!=len(set(usernames))
    result="Yes" if has_duplicates else "No"
    print(f"Duplicate Accounts Found:{result}")
detect_duplicates(["alice","bob","alice","charlie"])
# Out:
# Duplicate Accounts Found:Yes

# %%
#5.Healthcare appointment eligibility checker

def check_eligibility(age):
    status="Eligible" if age>=18 else "Not Eligible"
    print(f"Patient Age:{age}\nEligibility Status:{status}")
check_eligibility(23)
# Out:
# Patient Age:23
# Eligibility Status:Eligible

# %%
#6.Agriculture premium crop price filter

def filter_premium_crops(prices):
    premium=[p for p in prices if p>2000]
    print(f"Premium Crops:{premium}")
filter_premium_crops([6769,1700,2300,1500])
# Out:
# Premium Crops:[6769, 2300]

# %%
#7.System monitoring application health checker

def check_app_health(errors):
    if errors==0:
        status="Healthy"
    elif errors<=5:
        status="Minor Issues"
    else:
        status="Critical Issues"
    print(f"Error Count:{errors}\nSystem Status:{status}")
check_app_health(7)
# Out:
# Error Count:7
# System Status:Critical Issues

# %%
#8.Banking daily transaction limit checker

def check_transaction(amount):
    limit=50000
    status="Approved" if amount<=limit else "Rejected"
    print(f"Transaction Amount:{amount}\nTransaction Status:{status}")
check_transaction(75000)
# Out:
# Transaction Amount:75000
# Transaction Status:Rejected

# %%
#9.E-learning student attendance eligibility

def check_attendance(attended,total):
    percentage=(attended/total)*100
    status="Eligible" if percentage>=75 else "Not Eligible"
    print(f"Attendance Percentage:{percentage:.1f}\nExam Eligibility:{status}")
check_attendance(60,70)
# Out:
# Attendance Percentage:85.7
# Exam Eligibility:Eligible

# %%
#10.Smart electricity bill analyzer

def calculate_electricity_bill(units):
    if units<=100:
        bill=units*3
    elif units<=200:
        bill=(100*3)+((units-100)*5)
    else:
        bill=(100*3)+(100*5)+((units-200)*7)
    if bill<500:
        usage="Low Usage"
    elif bill<=1500:
        usage="Moderate Usage"
    else:
        usage="High Usage"
    print(f"Total Bill:{bill}\nUsage Status:{usage}")
calculate_electricity_bill(350)
# Out:
# Total Bill:1850
# Usage Status:High Usage
